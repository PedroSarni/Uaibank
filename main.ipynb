# %%
import pandas as pd
import numpy as np
import unicodedata

# %%
df=pd.read_csv("/home/sarni/Área de trabalho/1º Semestre/UaiBank/Projeto/data/Usuarios.csv")
df=df.set_index(["ID"])

#tratamento
def removendo_acentos(texto_acentos):
    sem_acento=unicodedata.normalize('NFKD', texto_acentos)
    return ''.join([x for x in sem_acento if not unicodedata.combining(x)])

df["Nome"]=df["Nome"].str.strip()
df["Nome"]=df["Nome"].str.title()
df["Estado"]=df["Estado"].str.upper()
df["Estado"]=df["Estado"].apply(removendo_acentos)

estados_brasileiros = {
    "ACRE": "AC",
    "ALAGOAS": "AL",
    "AMAPA": "AP",
    "AMAZONAS": "AM",
    "BAHIA": "BA",
    "CEARA": "CE",
    "DISTRITO FEDERAL": "DF",
    "ESPIRITO SANTO": "ES",
    "GOIAS": "GO",
    "MARANHAO": "MA",
    "MATO GROSSO": "MT",
    "MATO GROSSO DO SUL": "MS",
    "MINAS GERAIS": "MG",
    "PARA": "PA",
    "PARAIBA": "PB",
    "PARANA": "PR",
    "PERNAMBUCO": "PE",
    "PIAUI": "PI",
    "RIO DE JANEIRO": "RJ",
    "RIO GRANDE DO NORTE": "RN",
    "RIO GRANDE DO SUL": "RS",
    "RONDONIA": "RO",
    "RORAIMA": "RR",
    "SANTA CATARINA": "SC",
    "SAO PAULO": "SP",
    "SERGIPE": "SE",
    "TOCANTINS": "TO"
}
regioes_brasileiras = {
    "AC": "NORTE",
    "AP": "NORTE",
    "AM": "NORTE",
    "PA": "NORTE",
    "RO": "NORTE",
    "RR": "NORTE",
    "TO": "NORTE",

    "AL": "NORDESTE",
    "BA": "NORDESTE",
    "CE": "NORDESTE",
    "MA": "NORDESTE",
    "PB": "NORDESTE",
    "PE": "NORDESTE",
    "PI": "NORDESTE",
    "RN": "NORDESTE",
    "SE": "NORDESTE",

    "DF": "CENTRO-OESTE",
    "GO": "CENTRO-OESTE",
    "MT": "CENTRO-OESTE",
    "MS": "CENTRO-OESTE",

    "ES": "SUDESTE",
    "MG": "SUDESTE",
    "RJ": "SUDESTE",
    "SP": "SUDESTE",

    "PR": "SUL",
    "RS": "SUL",
    "SC": "SUL"
}
siglas = set(estados_brasileiros.values())

df["Estado"] = df["Estado"].where(df["Estado"].isin(siglas),df["Estado"].map(estados_brasileiros))
df["Região"] = df["Estado"].map(regioes_brasileiras)

display(df)
# Out:
#                     Nome Sexo  Idade Estado     Saldo        Região
# ID
# 1       Ana Clara Mendes    F     27     SP   2695.05       SUDESTE
# 2   Bruno Henrique Alves    M     34     SP   7482.40       SUDESTE
# 3     Camila R. Nogueira    F     22     SP   1015.75       SUDESTE
# 4          Diego Martins    M     41     SP  17329.75       SUDESTE
# 5        Elisa De Fátima    F     58     RJ    885.30       SUDESTE
# 6           Felipe Souza    M     19     RJ    875.15       SUDESTE
# 7          Gabriela Lima    F     31     RJ   5700.65       SUDESTE
# 8     Hugo César Pereira    M     46     MG   1356.45       SUDESTE
# 9        Isabela Moreira    F     25     MG   4949.85       SUDESTE
# 10     João Vitor Santos    M     29     MG   2300.55       SUDESTE
# 11         Karen Azevedo    F     38     PR   9020.35           SUL
# 12       Lucas  Ferreira    M     24     PR    596.30           SUL
# 13         Mariana Costa    F     33     PR  13480.10           SUL
# 14        Nicolas Barros    M     52     BA   1645.90      NORDESTE
# 15          Olívia Ramos    F     21     BA     95.25      NORDESTE
# 16     Pedro A. Carvalho    M     44     BA  15895.65      NORDESTE
# 17       Queila Monteiro    F     36     PE   3251.40      NORDESTE
# 18          Rafael Gomes    M     28     PE   2015.70      NORDESTE
# 19         Sofia Andrade    F     47     PE  11124.59      NORDESTE
# 20           Tiago Matos    M     32     CE   2130.15      NORDESTE
# 21        Úrsula Freitas    F     40     CE   7294.90      NORDESTE
# 22        Vinícius Rocha    M     26     CE   2940.05      NORDESTE
# 23        Wesley Cardoso    M     35     GO   9950.30  CENTRO-OESTE
# 24          Xênia Duarte    F     30     GO    520.35  CENTRO-OESTE
# 25       Yasmin Oliveira    F     23     GO   1660.00  CENTRO-OESTE
# 26            Zeca Moura    M     61     DF  15729.50  CENTRO-OESTE
# 27         Adriana Pires    F     42     DF   4091.20  CENTRO-OESTE
# 28         Bernardo Reis    M     20     DF   1020.20  CENTRO-OESTE
# 29     Carolina Teixeira    F     39     SC   8505.40           SUL
# 30         Danilo Farias    M     48     SC   5080.15           SUL
# 31        Evelyn Barbosa    F     27     RS    944.65           SUL
# 32         Fernando Melo    M     54     RS  23250.90           SUL
# 33         Giovana  Reis    F     18     RS     30.00           SUL
# 34    Heitor Vasconcelos    M     37     ES   4290.85       SUDESTE
# 35         Ingrid Castro    F     45     ES   4550.20       SUDESTE
# 36           Júlio Neves    M     33     MT  10560.00  CENTRO-OESTE
# 37         Larissa Prado    F     28     MT    150.95  CENTRO-OESTE
# 38        Mateus Ribeiro    M     49     MS   7090.86  CENTRO-OESTE
# 39        Natália Borges    F     26     MS   2447.80  CENTRO-OESTE
# 40           Otávio Paes    M     57     AM  17695.60         NORTE
# 41        Patrícia Cunha    F     34     AM   2290.90         NORTE
# 42           Renato Lobo    M     43     PA   5065.80         NORTE
# 43         Simone Vieira    F     51     PA   7379.50         NORTE
# 44          Tatiane Leal    F     29     PA   1684.70         NORTE
# 45       Ubirajara Costa    M     63     MA  24800.00      NORDESTE
# 46        Valéria Campos    F     41     MA   6349.90      NORDESTE
# 47      William Siqueira    M     24     MA    989.09      NORDESTE
# 48      Aline Cavalcante    F     36     PB   7530.40      NORDESTE
# 49          Caio Beltrão    M     31     PB   3190.85      NORDESTE
# 50          Débora Sales    F     28     PB   1095.60      NORDESTE
