# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/home/sarni/Área de trabalho/1º Semestre/UaiBank/Projeto/output/Usuarios.csv")
df=df.set_index(["ID"])
display(df)
# Out:
#      Nome Sexo  Idade Estado     Saldo
# ID
# 1   pedro    M    123  qwert  123456.0
# 2    wert    M   1234     sp  123456.0
